# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score

# %%
# Kagggle dataset link - https://www.kaggle.com/datasets/karthickveerakumar/salary-data-simple-linear-regression
df = pd.read_csv(r"F:\CodeCave\Machine Learning\Datasets\Salary_Data.csv")

# %%
print(df.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
print(df.isnull())
# Out:
#     YearsExperience  Salary
# 0             False   False
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# 5             False   False
# 6             False   False
# 7             False   False
# 8             False   False
# 9             False   False
# 10            False   False
# 11            False   False
# 12            False   False
# 13            False   False
# 14            False   False
# 15            False   False
# 16            False   False
# 17            False   False
# 18            False   False
# 19            False   False
# 20            False   False
# 21            False   False
# 22            False   False
# 23            False   False
# 24            False   False
# 25            False   False
# 26            False   False
# 27            False   False
# 28            False   False
# 29            False   False

# %%
print(df.isnull().sum())
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df = df.dropna()

# %%
X = df[['YearsExperience']]
Y = df['Salary']

# %%
X_train , X_test , Y_train ,Y_test = train_test_split(
        X , Y , test_size=0.2 , random_state=42
)

# %%
model =  LinearRegression()
model.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = model.predict(X_test)

# %%
MSE = mean_squared_error(Y_test , Y_predict)
print("MSE : ", MSE)
# Out:
# MSE :  49830096.85590839

# %%
r2 = r2_score(Y_test,Y_predict)
print("r2: ",r2)
# Out:
# r2:  0.9024461774180497

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_train, Y_train , color='blue',label="data points")
plt.plot(X_test, Y_predict , color="red", linewidth=2 ,label="regression line")
plt.title("Simple linear regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.show()
